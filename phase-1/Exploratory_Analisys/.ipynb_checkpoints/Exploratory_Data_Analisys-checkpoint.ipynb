# %%
"""Exploratory Analisys by library, once at the time"""
# Out:
# 'Exploratory Analisys by library, once at the time'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class Exploratory_Analisys:
    
    def __init__(self, input_file, Library, features):
        self.Data  = pd.read_csv(f'/home/barbara/Documents/DIFACQUIM/PPI_classifier/phase-1/Databases/{input_file}')
        self.Library= Library
        self.features = features
        print(str(Library), "Library contains : ", str(self.Data.shape[0]), "elements")
        
    def stats(self):
        Data = self.Data[self.features]
        stats = self.Data.describe()
        stats.to_csv((str(self.Library)+'_statistics.csv'), sep = ",")
        print(stats)
        
    def correlation(self):
        corr = self.Data.corr()
        f, ax = plt.subplots(figsize = (10,8))
        corr_matrix = sns.heatmap(corr,  annot=True)
        figure = corr_matrix.get_figure()    
        figure.savefig((str(self.Library)+'_correlation.png'), dpi=800)
        h = self.Data.hist(figsize=(10,12))
    
    def boxplot(self, feature):
        Data = self.Data
        sns.boxplot(x = "Library", y = Data[feature], data = Data, )
        plt.savefig("boxplot_feature.png")

# %%
features = ['HBA', 'HBD', 'RB', 'LogP', 'TPSA', 'MW', 'Heavy Atom', 'Ring Count', 'Fraction CSP3']

# %%
a = Exploratory_Analisys("Epidatabase_DB.csv", "Epidatabase", features)
# Out:
# Epidatabase Library contains :  16102 elements

# %%
a.stats()
# Out:
#          Unnamed: 0           HBA           HBD            RB          LogP  \
# count  16102.000000  16102.000000  16102.000000  16102.000000  16102.000000
# mean    8050.500000      5.392684      2.413365      6.568687      3.160889
# std     4648.391353      2.928055      2.659211      5.581916      1.923278
# min        0.000000      0.000000      0.000000      0.000000    -20.621620
# 25%     4025.250000      4.000000      1.000000      4.000000      2.273100
# 50%     8050.500000      5.000000      2.000000      6.000000      3.268850
# 75%    12075.750000      6.000000      3.000000      8.000000      4.210100
# max    16101.000000     53.000000     52.000000    103.000000     12.995400
#
#                TPSA            MW   Heavy Atom   Ring Count  Fraction CSP3
# count  16102.000000  16102.000000  16102.00000  16102.00000    16102.00000
# mean      92.879622    399.715558     28.26152     28.26152       28.26152
# std       70.416955    162.646037     11.48441     11.48441       11.48441
# min        0.000000     17.007000      1.00000      1.00000        1.00000
# 25%       67.150000    322.408000     22.00000     22.00000       22.00000
# 50%       84.220000    383.430000     27.00000     27.00000       27.00000
# 75%      105.600000    451.486000     32.00000     32.00000       32.00000
# max     1473.730000   3033.154000    207.00000    207.00000      207.00000

# %%
a.correlation()

# %%
a.boxplot("HBD")

# %%
pwd
# Out:
# '/home/barbara/Documents/DIFACQUIM/PPI_classifier/phase-1/Exploratory_Analisys'
